# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 27, 294142, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 30, 543941, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1050,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 42, 593287, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'Luna was a curious and '
#                                                      'adventurous child, with '
#                                                      'hair as white as the '
#                                                      'snow that fell on the '
#                                                      'mountains and eyes as '
#                                                      'blue as the sky on a '
#                                                      'clear day.\n'
#                                                      '\n'
#                                                      'Luna lived with her '
#                                                      'grandmother, a wise and '
#                                                      'kind woman who had spent '
#                                                      'her life studying the '
#                                                      'ancient magic that '
#                                                      'flowed through the land. '
#                                                      'The grandmother, known '
#                                                      'as the Moonweaver, '
#                                                      'taught Luna everything '
#                                                      'she knew, from the art '
#                                                      'of weaving spells to the '
#                                                      'secrets of the forest.\n'
#                                                      '\n'
#                                                      'One day, a great drought '
#                                                      'struck the land, and the '
#                                                      'crops began to wither '
#                                                      'and die. The villagers '
#                                                      'were worried, for they '
#                                                      'relied on the land for '
#                                                      'their livelihood. The '
#                                                      'Moonweaver called upon '
#                                                      'Luna to help her find a '
#                                                      'solution to the '
#                                                      'problem.\n'
#                                                      '\n'
#                                                      'Together, they set out '
#                                                      'into the forest, '
#                                                      'searching for a magical '
#                                                      'flower that was said to '
#                                                      'have the power to bring '
#                                                      'life-giving water to the '
#                                                      'parched earth. The '
#                                                      'flower, known as the '
#                                                      'Starbloom, was said to '
#                                                      'bloom only once a year, '
#                                                      'under the light of the '
#                                                      'full moon.\n'
#                                                      '\n'
#                                                      'As they journeyed deeper '
#                                                      'into the forest, Luna '
#                                                      'and the Moonweaver '
#                                                      'encountered many '
#                                                      'dangers, from fierce '
#                                                      'beasts to treacherous '
#                                                      'paths. But Luna was '
#                                                      'brave and determined, '
#                                                      'and with the '
#                                                      "Moonweaver's guidance, "
#                                                      'she was able to overcome '
#                                                      'every obstacle.\n'
#                                                      '\n'
#                                                      'Finally, after many '
#                                                      'hours of searching, they '
#                                                      'came upon a clearing, '
#                                                      'and in the center of it, '
#                                                      'they saw the Starbloom '
#                                                      'blooming in all its '
#                                                      'glory. It was a '
#                                                      'beautiful sight, with '
#                                                      'petals as white as snow '
#                                                      'and a center as bright '
#                                                      'as the stars.\n'
#                                                      '\n'
#                                                      'The Moonweaver '
#                                                      'instructed Luna to pick '
#                                                      'the flower, and as she '
#                                                      'did, a burst of magic '
#                                                      'energy flowed through '
#                                                      'her. The energy was so '
#                                                      'powerful that it filled '
#                                                      "Luna's heart with a "
#                                                      'sense of wonder and her '
#                                                      'spirit with a sense of '
#                                                      'purpose.\n'
#                                                      '\n'
#                                                      'With the Starbloom in '
#                                                      'hand, Luna and the '
#                                                      'Moonweaver returned to '
#                                                      'the village, where they '
#                                                      'used its magic to bring '
#                                                      'life-giving water to the '
#                                                      'parched earth. The crops '
#                                                      'began to grow once more, '
#                                                      'and the villagers were '
#                                                      'overjoyed.\n'
#                                                      '\n'
#                                                      'From that day on, Luna '
#                                                      'was known as the '
#                                                      'Starweaver, and she used '
#                                                      'her powers to bring '
#                                                      'magic and wonder to the '
#                                                      'world. And the '
#                                                      'Moonweaver, proud of her '
#                                                      "granddaughter's "
#                                                      'accomplishments, smiled '
#                                                      'knowing that the next '
#                                                      'generation of magic was '
#                                                      'in good hands.\n'
#                                                      '\n'
#                                                      'The story of Luna and '
#                                                      'the Starbloom was passed '
#                                                      'down through the '
#                                                      'generations, a reminder '
#                                                      'of the power of courage, '
#                                                      'determination, and the '
#                                                      'magic that lies within '
#                                                      'us all.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 42, 598492, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 522,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.414213562.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.41421356237.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 30, 545618, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 70,
#                  'status': 'success'}],
#   'status': 'complete',
#   'tokens_remaining': 1841221940,
#   'total_input_tokens': 87,
#   'total_output_tokens': 592,
#   'total_token_cost': 19640},
#  {'job_id': 1050, 'tokens_remaining': 1841193492})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 42, 957233, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 46, 654617, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1051,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 46, 654637, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951. '
#                                                      'However, it cannot be '
#                                                      'expressed as a finite '
#                                                      'decimal or fraction.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 46, 659894, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 75,
#                  'status': 'success'}],
#   'status': 'complete',
#   'tokens_remaining': 1841221252,
#   'total_input_tokens': 44,
#   'total_output_tokens': 75,
#   'total_token_cost': 688},
#  {'job_id': 1051, 'tokens_remaining': 1841213930})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1052, 'tokens_remaining': 1841213242}
# 200
# {'batch_submitted_timestamp': '2024-11-30T21:17:47.062025+00:00',
#  'depot_credits_available': 1841213242,
#  'job_id': 1052,
#  'status': 'pending',
#  'total_depot_credits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': '2024-11-30T15:17:47.062025-06:00',
#  'depot_credits_available': 1841220612,
#  'first_batch_item_completion_timestamp': '2024-11-30T15:17:50.707787-06:00',
#  'job_id': 1052,
#  'last_batch_item_completion_timestamp': '2024-11-30T15:17:50.707797-06:00',
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately '
#                                                     '1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': '2024-11-30T15:17:50.709925-06:00',
#                 'input_tokens': 44,
#                 'output_tokens': 69,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_credits_for_this_job': 640,
#  'total_input_tokens': 44,
#  'total_output_tokens': 69}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1053, 'tokens_remaining': 1841212602}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 15, 17, 58, 387453, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 18, 1, 772585, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1053,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 15, 18, 1, 772606, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It cannot be expressed as '
#                                                     'a finite decimal or '
#                                                     'fraction. \n'
#                                                     '\n'
#                                                     'The value of √2 is '
#                                                     'approximately '
#                                                     '1.4142135623730951. '
#                                                     'However, this is an '
#                                                     'approximation, and the '
#                                                     'actual value goes on '
#                                                     'forever without '
#                                                     'repeating.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 11, 30, 15, 18, 1, 777701, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 104,
#                 'status': 'success'}],
#  'status': 'complete',
#  'tokens_remaining': 1841219692,
#  'total_input_tokens': 44,
#  'total_output_tokens': 104,
#  'total_token_cost': 920}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1053/
