# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

# Note: This notebook was run on slow development hardware, for Client demonstration purposes.
#       The latencies are not representative of production hardware.

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 17, 57, 52, 544975, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840886388,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 57, 55, 167398, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1109,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 11, 220898, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'She was a curious and '
#                                                      'adventurous soul, with '
#                                                      'hair as white as the '
#                                                      'snow that fell gently on '
#                                                      'the mountains and eyes '
#                                                      'as blue as the clear '
#                                                      'night sky.\n'
#                                                      '\n'
#                                                      'Luna lived with her wise '
#                                                      'and kind grandmother, '
#                                                      'who was known throughout '
#                                                      'the village for her '
#                                                      'extraordinary gift – the '
#                                                      'ability to communicate '
#                                                      'with animals. Every day, '
#                                                      'Luna would watch in awe '
#                                                      'as her grandmother would '
#                                                      'sit by the river, '
#                                                      'surrounded by birds, '
#                                                      'rabbits, and even the '
#                                                      'occasional deer, who '
#                                                      'would come to visit her '
#                                                      'and share their '
#                                                      'secrets.\n'
#                                                      '\n'
#                                                      'One day, a great drought '
#                                                      'struck the land, and the '
#                                                      'crops began to wither '
#                                                      'and die. The villagers '
#                                                      'were worried, and they '
#                                                      "didn't know what to do. "
#                                                      "Luna's grandmother "
#                                                      'called upon her to join '
#                                                      'her by the river, and '
#                                                      'together, they sat in '
#                                                      'silence, watching the '
#                                                      'animals gather around '
#                                                      'them.\n'
#                                                      '\n'
#                                                      'As the sun began to set, '
#                                                      'a majestic eagle landed '
#                                                      'on a nearby branch, its '
#                                                      'feathers glistening in '
#                                                      "the fading light. Luna's "
#                                                      'grandmother reached out '
#                                                      'a hand, and the eagle '
#                                                      'nuzzled it gently. '
#                                                      'Suddenly, the eagle '
#                                                      'spoke to them in a voice '
#                                                      'that echoed in their '
#                                                      'minds.\n'
#                                                      '\n'
#                                                      '"The drought is not a '
#                                                      'natural phenomenon," the '
#                                                      'eagle said. "It is a '
#                                                      'sign of imbalance in the '
#                                                      'natural world. The '
#                                                      'humans have forgotten to '
#                                                      'respect and care for the '
#                                                      'land, and now the land '
#                                                      'is suffering."\n'
#                                                      '\n'
#                                                      "Luna's grandmother "
#                                                      'nodded, and the eagle '
#                                                      'continued. "But there is '
#                                                      'a way to restore '
#                                                      'balance. Follow the '
#                                                      'river to its source, and '
#                                                      'you will find the '
#                                                      'ancient tree, the '
#                                                      'guardian of the land. It '
#                                                      'holds the secrets of the '
#                                                      'earth, and if you listen '
#                                                      'carefully, it will tell '
#                                                      'you what to do."\n'
#                                                      '\n'
#                                                      'Without hesitation, Luna '
#                                                      'and her grandmother set '
#                                                      'off on their journey, '
#                                                      'following the river to '
#                                                      'its source. As they '
#                                                      'walked, the air grew '
#                                                      'thick with an '
#                                                      'otherworldly energy, and '
#                                                      'the trees seemed to lean '
#                                                      'in, as if listening to '
#                                                      'their conversation.\n'
#                                                      '\n'
#                                                      'Finally, they reached '
#                                                      'the ancient tree, its '
#                                                      'trunk twisted and '
#                                                      "gnarled with age. Luna's "
#                                                      'grandmother reached out '
#                                                      'a hand, and the tree '
#                                                      'spoke to them in a low, '
#                                                      'rumbling voice.\n'
#                                                      '\n'
#                                                      '"The humans have '
#                                                      'forgotten to honor the '
#                                                      'cycles of nature," the '
#                                                      'tree said. "They have '
#                                                      'forgotten to respect the '
#                                                      'land and its creatures. '
#                                                      'But you, Luna, have a '
#                                                      'special gift – the gift '
#                                                      'of listening. Listen to '
#                                                      'the land, and it will '
#                                                      'tell you what to do."\n'
#                                                      '\n'
#                                                      'Luna closed her eyes, '
#                                                      'and as she breathed in '
#                                                      'the scent of the tree, '
#                                                      'she felt a surge of '
#                                                      'energy flow through her. '
#                                                      'She listened to the '
#                                                      'land, and she heard its '
#                                                      'whispers – the rustling '
#                                                      'of leaves, the chirping '
#                                                      'of birds, the gentle '
#                                                      'babbling of the river.\n'
#                                                      '\n'
#                                                      'And in that moment, Luna '
#                                                      'knew what to do. She '
#                                                      'returned to the village, '
#                                                      'and with her grandmother '
#                                                      'by her side, she shared '
#                                                      'the secrets of the land '
#                                                      'with the villagers. '
#                                                      'Together, they worked to '
#                                                      'restore balance to the '
#                                                      'natural world, honoring '
#                                                      'the cycles of nature and '
#                                                      'respecting the creatures '
#                                                      'that lived within it.\n'
#                                                      '\n'
#                                                      'And so, the drought '
#                                                      'ended, and the crops '
#                                                      'began to grow once more. '
#                                                      'The villagers prospered, '
#                                                      "and Luna's grandmother "
#                                                      'smiled, knowing that her '
#                                                      'granddaughter had '
#                                                      'discovered her own '
#                                                      'special gift – the gift '
#                                                      'of listening to the '
#                                                      'land.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 11, 226096, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 663,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 17, 57, 55, 169097, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 75,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 24312,
#   'total_input_tokens': 87,
#   'total_output_tokens': 738},
#  {'job_id': 1109, 'permits_remaining': 1840862612})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 11, 441843, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840885836,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 14, 280188, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1110,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 14, 280188, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.41421356237.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.41421356237.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 14, 285442, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 58,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 552,
#   'total_input_tokens': 44,
#   'total_output_tokens': 58},
#  {'job_id': 1110, 'permits_remaining': 1840878378})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1111, 'permits_remaining': 1840877826}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 14, 446610, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840877826,
#  'job_id': 1111,
#  'status': 'pending',
#  'total_depot_permits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 14, 446610, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840885076,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 18, 345710, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1111,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 18, 345710, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a simple '
#                                                     'fraction. Its decimal '
#                                                     'representation is '
#                                                     'approximately '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 18, 350830, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 84,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 760,
#  'total_input_tokens': 44,
#  'total_output_tokens': 84}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1112, 'permits_remaining': 1840877066}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 25, 509497, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840884388,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 28, 420368, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1112,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 28, 420368, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 17, 58, 28, 425491, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 75,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 688,
#  'total_input_tokens': 44,
#  'total_output_tokens': 75}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1112/
