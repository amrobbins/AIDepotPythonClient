# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

# Note: This notebook was running using slow development hardware, for demonstration purposes.
#       The latencies are not indicative of production hardware.

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 7, 848865, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1841177828,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 11, 158403, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1058,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 23, 203034, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'Luna was a curious and '
#                                                      'adventurous child, with '
#                                                      'eyes as bright as the '
#                                                      'stars and hair as dark '
#                                                      'as the night sky.\n'
#                                                      '\n'
#                                                      'One evening, as the sun '
#                                                      'dipped below the '
#                                                      'horizon, Luna wandered '
#                                                      "into the village's "
#                                                      'ancient forest, '
#                                                      'searching for a rare '
#                                                      'flower that bloomed only '
#                                                      'under the light of the '
#                                                      'full moon. The villagers '
#                                                      'called it the '
#                                                      '"Moonbloom," and it was '
#                                                      'said to have the power '
#                                                      'to grant wishes to those '
#                                                      'who possessed it.\n'
#                                                      '\n'
#                                                      'As Luna walked deeper '
#                                                      'into the forest, the '
#                                                      'trees grew taller and '
#                                                      'the shadows grew darker. '
#                                                      'She heard the hooting of '
#                                                      'owls and the rustling of '
#                                                      "leaves, but she didn't "
#                                                      'let fear stop her. She '
#                                                      'followed a narrow path '
#                                                      'that wound its way '
#                                                      'through the trees, her '
#                                                      'heart pounding with '
#                                                      'excitement.\n'
#                                                      '\n'
#                                                      'Suddenly, a soft light '
#                                                      'appeared in the '
#                                                      'distance. Luna quickened '
#                                                      'her pace, her eyes fixed '
#                                                      'on the glow. As she '
#                                                      'approached, she saw that '
#                                                      'it was a beautiful '
#                                                      'garden, filled with '
#                                                      'flowers of every color '
#                                                      'and scent. In the center '
#                                                      'of the garden, a single '
#                                                      'Moonbloom bloomed, its '
#                                                      'petals shining like '
#                                                      'silver in the '
#                                                      'moonlight.\n'
#                                                      '\n'
#                                                      'Luna reached out and '
#                                                      'gently plucked the '
#                                                      'flower, feeling its '
#                                                      'delicate petals unfold '
#                                                      'in her hand. As she did, '
#                                                      'a soft voice whispered '
#                                                      'in her ear, "What is '
#                                                      "your heart's desire, "
#                                                      'little one?"\n'
#                                                      '\n'
#                                                      'Luna thought for a '
#                                                      'moment, then replied, "I '
#                                                      'wish for the ability to '
#                                                      'heal any hurt or '
#                                                      'sickness, so that I can '
#                                                      'help those in need and '
#                                                      'bring joy to those '
#                                                      'around me."\n'
#                                                      '\n'
#                                                      'The voice replied, "Your '
#                                                      'wish is granted, Luna. '
#                                                      'From this day forward, '
#                                                      'you will possess the '
#                                                      'power to heal with a '
#                                                      'touch of your hand."\n'
#                                                      '\n'
#                                                      'And with that, Luna felt '
#                                                      'a surge of energy flow '
#                                                      'through her body. She '
#                                                      'knew that she had been '
#                                                      'given a great gift, and '
#                                                      'she vowed to use it to '
#                                                      'make the world a '
#                                                      'brighter and more loving '
#                                                      'place.\n'
#                                                      '\n'
#                                                      'From that day on, Luna '
#                                                      'used her newfound power '
#                                                      'to help those in need, '
#                                                      'and her kindness and '
#                                                      'compassion inspired '
#                                                      'others to do the same. '
#                                                      'And the villagers would '
#                                                      'say that whenever the '
#                                                      "moon was full, Luna's "
#                                                      'heart shone as brightly '
#                                                      'as the stars, and her '
#                                                      'spirit was as gentle as '
#                                                      "the breeze on a summer's "
#                                                      'day.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 23, 208234, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 465,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.41421356237.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 11, 159536, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 60,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 17496,
#   'total_input_tokens': 87,
#   'total_output_tokens': 525},
#  {'job_id': 1058, 'permits_remaining': 1841147236})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 23, 420045, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1841177156,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 26, 261689, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1059,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 26, 261689, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 16, 31, 26, 266921, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 73,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 672,
#   'total_input_tokens': 44,
#   'total_output_tokens': 73},
#  {'job_id': 1059, 'permits_remaining': 1841169818})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1060, 'permits_remaining': 1841169146}
# 200
# {'batch_submitted_timestamp': '2024-11-30T22:31:26.400064+00:00',
#  'depot_permits_available': 1841169146,
#  'job_id': 1060,
#  'status': 'pending',
#  'total_depot_permits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': '2024-11-30T16:31:26.400064-06:00',
#  'depot_permits_available': 1841176308,
#  'first_batch_item_completion_timestamp': '2024-11-30T16:31:29.321548-06:00',
#  'job_id': 1060,
#  'last_batch_item_completion_timestamp': '2024-11-30T16:31:29.321548-06:00',
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.41421356237. This '
#                                                     'value is a non-repeating, '
#                                                     'non-terminating decimal, '
#                                                     'which is a characteristic '
#                                                     'of irrational numbers.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': '2024-11-30T16:31:29.326637-06:00',
#                 'input_tokens': 44,
#                 'output_tokens': 95,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 848,
#  'total_input_tokens': 44,
#  'total_output_tokens': 95}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1062, 'permits_remaining': 1841167714}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 16, 34, 39, 166197, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1841175140,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 34, 40, 682818, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1062,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 16, 34, 40, 682818, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 11, 30, 16, 34, 40, 688014, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 62,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 584,
#  'total_input_tokens': 44,
#  'total_output_tokens': 62}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1061/
