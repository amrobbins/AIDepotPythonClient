# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

# Note: This notebook was run on slow development hardware, for Client demonstration purposes.
#       The latencies are not representative of production hardware.

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 15, 43, 53, 852335, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840989124,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 43, 56, 332162, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1091,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 6, 369714, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'Luna was a curious and '
#                                                      'adventurous child, with '
#                                                      'hair as black as the '
#                                                      'night sky and eyes that '
#                                                      'shone like the stars.\n'
#                                                      '\n'
#                                                      'One evening, as the sun '
#                                                      'dipped below the '
#                                                      'horizon, Luna wandered '
#                                                      'into the village square, '
#                                                      'where a group of elderly '
#                                                      'villagers were gathered '
#                                                      'around a small fire. '
#                                                      'They were telling '
#                                                      'stories of the ancient '
#                                                      'magic that once flowed '
#                                                      'through the land, of the '
#                                                      'spirits that danced in '
#                                                      'the mountains, and of '
#                                                      'the secrets that lay '
#                                                      'hidden in the forest.\n'
#                                                      '\n'
#                                                      'Luna listened with wide '
#                                                      'eyes, her imagination '
#                                                      'running wild with the '
#                                                      'tales of wonder and '
#                                                      'enchantment. As the '
#                                                      'night wore on, the '
#                                                      'villagers began to '
#                                                      'disperse, leaving Luna '
#                                                      'alone by the fire.\n'
#                                                      '\n'
#                                                      'Suddenly, a gentle '
#                                                      'breeze rustled the '
#                                                      'leaves of the nearby '
#                                                      'trees, and a small, '
#                                                      'delicate wing fluttered '
#                                                      'into view. Luna gasped '
#                                                      'as a tiny fairy emerged '
#                                                      'from the shadows, her '
#                                                      'wings shimmering like '
#                                                      'iridescent glass.\n'
#                                                      '\n'
#                                                      'The fairy, whose name '
#                                                      'was Aria, spoke to Luna '
#                                                      'in a voice like the '
#                                                      'tinkling of a bell. "I '
#                                                      'have been watching you, '
#                                                      'child," she said. "You '
#                                                      'have a heart full of '
#                                                      'wonder and a soul that '
#                                                      'yearns for magic. Would '
#                                                      'you like to see the '
#                                                      'secrets of the forest?"\n'
#                                                      '\n'
#                                                      "Luna's eyes sparkled "
#                                                      'with excitement as Aria '
#                                                      'took her hand and led '
#                                                      'her into the darkness. '
#                                                      'Together, they danced '
#                                                      'through the trees, the '
#                                                      "fairy's wings glowing "
#                                                      'like a lantern in the '
#                                                      'night. They chased after '
#                                                      'fireflies, played '
#                                                      'hide-and-seek among the '
#                                                      'ferns, and laughed with '
#                                                      'the creatures of the '
#                                                      'forest.\n'
#                                                      '\n'
#                                                      'As the night wore on, '
#                                                      'Luna felt her heart fill '
#                                                      'with a sense of '
#                                                      'belonging and connection '
#                                                      'to the natural world. '
#                                                      'She knew that she would '
#                                                      'never forget this '
#                                                      'magical night, and that '
#                                                      'she would always carry '
#                                                      'the secrets of the '
#                                                      'forest in her heart.\n'
#                                                      '\n'
#                                                      'From that day on, Luna '
#                                                      'and Aria became the best '
#                                                      'of friends, exploring '
#                                                      'the mysteries of the '
#                                                      'forest and sharing its '
#                                                      'secrets with the '
#                                                      'villagers. And as the '
#                                                      'years passed, the '
#                                                      'village became a place '
#                                                      'of wonder and '
#                                                      'enchantment, where magic '
#                                                      'flowed through the air '
#                                                      'and the spirits of the '
#                                                      'mountains danced in the '
#                                                      'night.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 6, 376006, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 443,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'simple fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951. '
#                                                      'However, it cannot be '
#                                                      'expressed as a finite '
#                                                      'decimal or fraction.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 15, 43, 56, 334446, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 86,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 17624,
#   'total_input_tokens': 87,
#   'total_output_tokens': 529},
#  {'job_id': 1091, 'permits_remaining': 1840958660})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 6, 615166, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840988436,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 9, 431676, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1092,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 9, 431676, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 9, 436323, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 75,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 688,
#   'total_input_tokens': 44,
#   'total_output_tokens': 75},
#  {'job_id': 1092, 'permits_remaining': 1840981114})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1093, 'permits_remaining': 1840980426}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 9, 571686, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840980426,
#  'job_id': 1093,
#  'status': 'pending',
#  'total_depot_permits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 9, 571686, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840987772,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 12, 490597, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1093,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 12, 490597, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. Its '
#                                                     'value is approximately '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     "It's approximately equal "
#                                                     'to 1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 12, 495838, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 72,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 664,
#  'total_input_tokens': 44,
#  'total_output_tokens': 72}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1094, 'permits_remaining': 1840979762}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 19, 799579, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840987100,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 22, 559797, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1094,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 22, 559797, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a simple '
#                                                     'fraction. Its decimal '
#                                                     'representation is '
#                                                     'approximately '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 15, 44, 22, 565279, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 73,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 672,
#  'total_input_tokens': 44,
#  'total_output_tokens': 73}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1094/
