# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

# Note: This notebook was run on slow development hardware, for Client demonstration purposes.
#       The latencies are not representative of production hardware.

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 18, 271921, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1841009228,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 20, 902030, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1086,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 33, 962050, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'Luna was known '
#                                                      'throughout the village '
#                                                      'for her extraordinary '
#                                                      'gift – she could '
#                                                      'communicate with the '
#                                                      'creatures of the '
#                                                      'forest.\n'
#                                                      '\n'
#                                                      'Every morning, Luna '
#                                                      'would wake up before '
#                                                      'dawn and venture into '
#                                                      'the woods, where she '
#                                                      'would sit by a babbling '
#                                                      'brook and listen to the '
#                                                      'whispers of the trees, '
#                                                      'the songs of the birds, '
#                                                      'and the rustling of the '
#                                                      'leaves. The creatures of '
#                                                      'the forest had grown '
#                                                      "accustomed to Luna's "
#                                                      'presence, and they would '
#                                                      'often gather around her, '
#                                                      'sharing their secrets '
#                                                      'and stories.\n'
#                                                      '\n'
#                                                      'One day, a wise old owl '
#                                                      'named Orion perched on a '
#                                                      'nearby branch, gazing at '
#                                                      'Luna with piercing eyes. '
#                                                      '"Luna, the forest is in '
#                                                      'trouble," Orion said, '
#                                                      'his voice low and '
#                                                      'urgent. "A great drought '
#                                                      'has struck the land, and '
#                                                      'the plants are beginning '
#                                                      'to wither and die. The '
#                                                      'creatures are struggling '
#                                                      'to find food and '
#                                                      'water."\n'
#                                                      '\n'
#                                                      "Luna's heart went out to "
#                                                      'the creatures, and she '
#                                                      'knew she had to do '
#                                                      'something to help. She '
#                                                      'closed her eyes, took a '
#                                                      'deep breath, and focused '
#                                                      'her mind on the forest. '
#                                                      'She could feel the pulse '
#                                                      'of the trees, the beat '
#                                                      'of the earth, and the '
#                                                      'rhythm of the creatures. '
#                                                      'And then, a vision '
#                                                      'appeared before her – a '
#                                                      'vision of a hidden '
#                                                      'spring, deep within the '
#                                                      'forest, where the water '
#                                                      'was crystal clear and '
#                                                      'the plants were lush and '
#                                                      'green.\n'
#                                                      '\n'
#                                                      'Luna shared her vision '
#                                                      'with Orion, and '
#                                                      'together, they set out '
#                                                      'to find the hidden '
#                                                      'spring. They traveled '
#                                                      'through the forest, '
#                                                      "following Luna's "
#                                                      'guidance, until they '
#                                                      'reached a clearing '
#                                                      'surrounded by a ring of '
#                                                      'mushrooms. In the center '
#                                                      'of the clearing stood a '
#                                                      'magnificent tree, its '
#                                                      'branches stretching '
#                                                      'towards the sky like a '
#                                                      "giant's fingers.\n"
#                                                      '\n'
#                                                      'Luna reached out and '
#                                                      'touched the trunk of the '
#                                                      'tree, and suddenly, the '
#                                                      'air was filled with a '
#                                                      'soft, golden light. The '
#                                                      'light grew brighter and '
#                                                      'brighter, until it '
#                                                      'illuminated the entire '
#                                                      'forest, and the '
#                                                      'creatures emerged from '
#                                                      'their hiding places, '
#                                                      'blinking in the sudden '
#                                                      'radiance.\n'
#                                                      '\n'
#                                                      'And then, the most '
#                                                      'amazing thing happened – '
#                                                      'the plants began to '
#                                                      'grow, the flowers '
#                                                      'bloomed, and the trees '
#                                                      'regained their vibrancy. '
#                                                      'The creatures cheered '
#                                                      'and celebrated, and Luna '
#                                                      'smiled, knowing that she '
#                                                      'had helped to save the '
#                                                      'forest.\n'
#                                                      '\n'
#                                                      'From that day on, Luna '
#                                                      'was known as the '
#                                                      'guardian of the forest, '
#                                                      'and the creatures looked '
#                                                      'up to her as a hero. And '
#                                                      'every time she sat by '
#                                                      'the brook, listening to '
#                                                      'the whispers of the '
#                                                      'trees, she knew that she '
#                                                      'was connected to the '
#                                                      'natural world, and that '
#                                                      'she had the power to '
#                                                      'make a difference.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 33, 968062, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 525,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.41421356237 (and goes '
#                                                      'on infinitely).',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 20, 903632, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 78,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 19992,
#   'total_input_tokens': 87,
#   'total_output_tokens': 603},
#  {'job_id': 1086, 'permits_remaining': 1840981132})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 34, 198094, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1841008660,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 37, 18879, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1087,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 37, 18879, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      "number. It's "
#                                                      'approximately equal to '
#                                                      '1.41421356237.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 37, 24001, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 60,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 568,
#   'total_input_tokens': 44,
#   'total_output_tokens': 60},
#  {'job_id': 1087, 'permits_remaining': 1841001218})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1088, 'permits_remaining': 1841000650}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 37, 153981, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1841000650,
#  'job_id': 1088,
#  'status': 'pending',
#  'total_depot_permits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 37, 153981, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1841007972,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 40, 74552, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1088,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 40, 74552, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 40, 79909, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 75,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 688,
#  'total_input_tokens': 44,
#  'total_output_tokens': 75}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1089, 'permits_remaining': 1840999962}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 47, 366946, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1841007436,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 49, 137955, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1089,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 49, 137955, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 is '
#                                                     'an irrational number, '
#                                                     'approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 11, 30, 18, 34, 49, 143385, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 56,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 536,
#  'total_input_tokens': 44,
#  'total_output_tokens': 56}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1089/
