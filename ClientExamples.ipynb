# %%
subscriber_id = '<your_subscriber_email@example.com>'
api_key = '<your_api_key>'

# Note: This notebook was run on slow development hardware, for Client demonstration purposes.
#       The latencies are not representative of production hardware.

import AIDepot

from pprint import pprint
import time

client = AIDepot.Client(subscriber_id=subscriber_id, api_key=api_key)


conversations = [
    {
        "messages": [{
            "role": "user", "content": "Can you tell me a short story?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 1
    },
    {
        "messages": [{
            "role": "user", "content": "What is the square root of 2?"
        }],
        "temperature": 0.3,
        "top_p": 1,
        "max_tokens": 1000,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "n": 2
    },
]

job = {
    'sla': 'priority',
    'conversations': conversations
}
# Out:
# {'IPKernelApp': {'connection_file': '/home/andrew-local/.local/share/jupyter/runtime/kernel-ebaccf16-a5d7-4555-98d2-d410aa88d3c2.json'}}

# %%
# Submit a job and wait for the response:

response = client.submit_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 4, 396390, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840916028,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 6, 715362, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1100,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 21, 762139, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'Once upon a time, in a '
#                                                      'small village nestled '
#                                                      'between two great '
#                                                      'mountains, there lived a '
#                                                      'young girl named Luna. '
#                                                      'Luna was a curious and '
#                                                      'adventurous soul, with '
#                                                      'eyes as bright as the '
#                                                      'stars and hair as black '
#                                                      'as the night sky.\n'
#                                                      '\n'
#                                                      'One evening, as the sun '
#                                                      'dipped below the '
#                                                      'horizon, Luna wandered '
#                                                      'into the village square, '
#                                                      'where a group of elderly '
#                                                      'villagers were gathered '
#                                                      'around a small fire. '
#                                                      'They were telling '
#                                                      'stories of the ancient '
#                                                      'magic that once flowed '
#                                                      'through the land, of the '
#                                                      'great spirits that '
#                                                      'roamed the mountains, '
#                                                      'and of the hidden '
#                                                      'treasures that lay '
#                                                      'hidden beneath the '
#                                                      'earth.\n'
#                                                      '\n'
#                                                      "Luna's ears perked up as "
#                                                      'she listened to the '
#                                                      'tales, her imagination '
#                                                      'running wild with '
#                                                      'visions of dragons and '
#                                                      'unicorns, of hidden '
#                                                      'temples and ancient '
#                                                      'artifacts. She felt a '
#                                                      'thrill of excitement as '
#                                                      'she realized that the '
#                                                      'stories were not just '
#                                                      'mere fantasies, but were '
#                                                      'rooted in the history '
#                                                      'and culture of her '
#                                                      'village.\n'
#                                                      '\n'
#                                                      'As the night wore on, '
#                                                      'the villagers noticed '
#                                                      "Luna's fascination with "
#                                                      'the stories and beckoned '
#                                                      'her to come closer. They '
#                                                      'told her of a hidden '
#                                                      'cave deep within the '
#                                                      'mountains, where a '
#                                                      'magical spring bubbled '
#                                                      'up from the earth, '
#                                                      'granting wishes to those '
#                                                      'who drank from it.\n'
#                                                      '\n'
#                                                      "Luna's heart skipped a "
#                                                      'beat as she listened to '
#                                                      'the tale. She had always '
#                                                      'felt a deep connection '
#                                                      'to the natural world, '
#                                                      'and the idea of a '
#                                                      'magical spring that '
#                                                      'could grant wishes was '
#                                                      'too enticing to resist. '
#                                                      'She begged the villagers '
#                                                      'to take her to the cave, '
#                                                      'and after some '
#                                                      'hesitation, they agreed '
#                                                      'to guide her on the '
#                                                      'journey.\n'
#                                                      '\n'
#                                                      'As they climbed higher '
#                                                      'into the mountains, the '
#                                                      'air grew cooler and the '
#                                                      'stars twinkled brighter '
#                                                      'in the sky. Luna felt a '
#                                                      'sense of wonder and awe '
#                                                      'as she gazed up at the '
#                                                      'towering peaks, feeling '
#                                                      'the magic of the land '
#                                                      'pulsing through her '
#                                                      'veins.\n'
#                                                      '\n'
#                                                      'Finally, they reached '
#                                                      'the cave, a hidden '
#                                                      'entrance guarded by a '
#                                                      'wise old owl who looked '
#                                                      'at Luna with wise, '
#                                                      'knowing eyes. The '
#                                                      'villagers led her to the '
#                                                      'magical spring, where '
#                                                      'she cupped her hands and '
#                                                      'drank from the cool, '
#                                                      'clear water.\n'
#                                                      '\n'
#                                                      'As she drank, Luna felt '
#                                                      'a surge of energy and a '
#                                                      'sense of clarity wash '
#                                                      'over her. She closed her '
#                                                      'eyes and focused on her '
#                                                      "heart's desire, and when "
#                                                      'she opened them again, '
#                                                      'she saw that the cave '
#                                                      'was filled with a soft, '
#                                                      'ethereal light.\n'
#                                                      '\n'
#                                                      'The villagers smiled at '
#                                                      'her, and the wise old '
#                                                      'owl nodded its head in '
#                                                      'approval. Luna knew that '
#                                                      'she had been granted a '
#                                                      'wish, but she also knew '
#                                                      'that the true magic lay '
#                                                      'not in the wish itself, '
#                                                      'but in the journey she '
#                                                      'had taken to get there.\n'
#                                                      '\n'
#                                                      'From that day on, Luna '
#                                                      'returned to the cave '
#                                                      'often, drinking from the '
#                                                      'magical spring and '
#                                                      'listening to the stories '
#                                                      'of the villagers. She '
#                                                      'knew that the true magic '
#                                                      'of the land lay not in '
#                                                      'the artifacts or the '
#                                                      'treasures, but in the '
#                                                      'connections she made '
#                                                      'with the people and the '
#                                                      'natural world around '
#                                                      'her.\n'
#                                                      '\n'
#                                                      'And so, Luna lived a '
#                                                      'life filled with wonder, '
#                                                      'awe, and a deep '
#                                                      'connection to the magic '
#                                                      'of the land, always '
#                                                      'remembering the wise '
#                                                      'words of the villagers: '
#                                                      '"The true magic lies not '
#                                                      'in the destination, but '
#                                                      'in the journey itself."',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 21, 767328, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 43,
#                  'output_tokens': 619,
#                  'status': 'success'},
#                 {'batch_index': 1,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It cannot be '
#                                                      'expressed as a finite '
#                                                      'decimal or fraction. \n'
#                                                      '\n'
#                                                      'The approximate value of '
#                                                      'the square root of 2 is '
#                                                      '1.4142135623730951. '
#                                                      'However, this is an '
#                                                      'approximation, and the '
#                                                      'actual value goes on '
#                                                      'infinitely without '
#                                                      'repeating.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 6, 717017, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 110,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 24024,
#   'total_input_tokens': 87,
#   'total_output_tokens': 729},
#  {'job_id': 1100, 'permits_remaining': 1840891964})

# %%
# From an async context, get a future response
# Note that this is a Jupyter notebook, so I can await async functions directly
# Normally this would be called within an async function like:
#
# async def send_job():
#     future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
#     response = await future_response

job = {
    'sla': 'batch',
    'conversations': [conversations[1]]
}

future_response = client.submit_job_async(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
response = await future_response
pprint(response)
# Out:
# (200,
#  {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 21, 988845, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'depot_permits_available': 1840915340,
#   'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 24, 811518, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'job_id': 1101,
#   'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 24, 811518, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#   'responses': [{'batch_index': 0,
#                  'choices': [{'finish_reason': 'stop',
#                               'index': 0,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None},
#                              {'finish_reason': 'stop',
#                               'index': 1,
#                               'logprobs': None,
#                               'message': {'audio': None,
#                                           'content': 'The square root of 2 '
#                                                      '(√2) is an irrational '
#                                                      'number, which means it '
#                                                      'cannot be expressed as a '
#                                                      'finite decimal or '
#                                                      'fraction. It is '
#                                                      'approximately equal to '
#                                                      '1.4142135623730951.',
#                                           'function_call': None,
#                                           'refusal': None,
#                                           'role': 'assistant',
#                                           'tool_calls': []},
#                               'stop_reason': None}],
#                  'completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 24, 816570, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                  'input_tokens': 44,
#                  'output_tokens': 75,
#                  'status': 'success'}],
#   'status': 'complete',
#   'total_depot_permits_for_this_job': 688,
#   'total_input_tokens': 44,
#   'total_output_tokens': 75},
#  {'job_id': 1101, 'permits_remaining': 1840908018})

# %%
# Start a job without waiting for it to finish:
# Check the result immediately
# Wait a bit and check the result again

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)


# Wait a while and make another call to get_job_results
time.sleep(10)
http_response_code, response_message = client.get_job_result(AIDepot.Resources.LLM_JOB_RESULTS, job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1102, 'permits_remaining': 1840907330}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 25, 43633, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840907330,
#  'job_id': 1102,
#  'status': 'pending',
#  'total_depot_permits_for_this_job': None,
#  'total_input_tokens': None,
#  'total_output_tokens': None}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 25, 43633, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840914548,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 27, 865645, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1102,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 27, 865645, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number, '
#                                                     'which means it cannot be '
#                                                     'expressed as a finite '
#                                                     'decimal or fraction. It '
#                                                     'is approximately equal to '
#                                                     '1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 27, 869960, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 88,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 792,
#  'total_input_tokens': 44,
#  'total_output_tokens': 88}

# %%
# Start a job without waiting for it to finish:
# Do some other processing
# Connect to AIDepot to wait for the job to finish

http_response_code, response_message = client.start_job(AIDepot.Resources.MISTRAL_7B_MESSAGE, job)
print(http_response_code)
pprint(response_message)
job_id = response_message['job_id']

j = 0
for i in range(1000):
    j += i

http_response_code, response_message = client.connect_and_listen_for_status(job_id)
print(http_response_code)
pprint(response_message)
# Out:
# 201
# {'job_id': 1103, 'permits_remaining': 1840906538}
# 200
# {'batch_submitted_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 35, 304724, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'depot_permits_available': 1840913980,
#  'first_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 36, 930312, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'job_id': 1103,
#  'last_batch_item_completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 36, 930312, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#  'responses': [{'batch_index': 0,
#                 'choices': [{'finish_reason': 'stop',
#                              'index': 0,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.4142135623730951.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None},
#                             {'finish_reason': 'stop',
#                              'index': 1,
#                              'logprobs': None,
#                              'message': {'audio': None,
#                                          'content': 'The square root of 2 (√2) '
#                                                     'is an irrational number. '
#                                                     'It is approximately equal '
#                                                     'to 1.41421356237.',
#                                          'function_call': None,
#                                          'refusal': None,
#                                          'role': 'assistant',
#                                          'tool_calls': []},
#                              'stop_reason': None}],
#                 'completion_timestamp': datetime.datetime(2024, 12, 1, 16, 39, 36, 935353, tzinfo=zoneinfo.ZoneInfo(key='America/Chicago')),
#                 'input_tokens': 44,
#                 'output_tokens': 60,
#                 'status': 'success'}],
#  'status': 'complete',
#  'total_depot_permits_for_this_job': 568,
#  'total_input_tokens': 44,
#  'total_output_tokens': 60}

# %%
# In case you want to connect by some other means than by using the client,
# the client can generate the http routes, and the websocket routes that are
# used for listening for jobs to finish:

http_route = client.build_http_route(AIDepot.Resources.LLAMA3_1_NEMOTRON_70B_MESSAGE)
print(http_route)

# Reusing the job_id from the previous cell:
websocket_route = client.build_websocket_route(job_id)
print(websocket_route)
# Out:
# https://aidepot.net/api/v1/llm/llama_3_1_nemotron_70b/message/
# wss://aidepot.net/api/ws/status/andrewrobbins%40hotmail.com/1103/
